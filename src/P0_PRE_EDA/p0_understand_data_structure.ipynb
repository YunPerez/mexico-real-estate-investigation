# %% [markdown]
# # General EDA of SHIF Data
#
# @roman
#
# 29 Sep, 2024

# %% [markdown]
# ---
# # Settings

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Settings
# show 100 columns in pandas
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ---
# # Data

# %%
# read csv
df_properties_2019 = pd.read_csv('../../data/new/ITAM_2019_CSV.csv')
df_properties_2019
# Out:
#         1/2 BAÑOS  BAÑOS  CLASE INMUEBLES ZONA  \
# 0               0      1                     2
# 1               1      4                     4
# 2               0      1                     3
# 3               1      1                     4
# 4               1      2                     4
# ...           ...    ...                   ...
# 500762          1      3                     5
# 500763          1      4                     5
# 500764          1      4                     5
# 500765          1      4                     5
# 500766          1      4                     5
#
#                                       COLONIA                  CONSTRUCTOR  \
# 0                            SAN ANDRES METLA                    NO APLICA
# 1                                   NO APLICA                    NO APLICA
# 2                                BUENOS AIRES                    NO APLICA
# 3                               SANTA CECILIA                    NO APLICA
# 4                                   ARBOLEDAS                    NO APLICA
# ...                                       ...                          ...
# 500762  FRACC RES CAMPESTRE CONDADO SAYAVEDRA                    NO APLICA
# 500763       FRACCIONAMIENTO VILLAS LA JOYA 2   RODRIGUEZ SILLER ALEJANDRO
# 500764    FRACCIONAMIENTO PRIVADA SAN AGUSTÍN  RAUL ALEJANDRO MONCADA LEAL
# 500765    FRACCIONAMIENTO VALLE DE SANTA CRUZ                      GRUMART
# 500766           NUEVA RINCONADA DE LOS ANDES                    NO APLICA
#
#            CP  CUENTA_PREDIAL DESCRIPCION_INSTALACION_ESPECIAL_COMUNES  \
# 0       56680             NaN                                      NaN
# 1       97345             NaN                                      NaN
# 2       23456             NaN                                      NaN
# 3       37806             NaN                                      NaN
# 4       29960             NaN                                      NaN
# ...       ...             ...                                      ...
# 500762  52938             NaN                                        3
# 500763  25297             NaN                                      NaN
# 500764  67350             NaN                                      NaN
# 500765  66362             NaN                                      NaN
# 500766  78218             NaN                                NO APLICA
#
#        DESCRIPCION_INSTALACION_ESPECIAL_PRIVATIVAS  \
# 0                                              NaN
# 1                                              NaN
# 2                                       ESTRUCTURA
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 500762                                         NaN
# 500763                                         NaN
# 500764                                         NaN
# 500765                                         NaN
# 500766                                         NaN
#
#        DESCRIPCION_OBRA_COMPLEMENTARIA_COMUN  EDAD MESES  ESTACIONAMIENTO  \
# 0                                        NaN         168                2
# 1                                        NaN           0                2
# 2                                        NaN         228                1
# 3                                        NaN         240                2
# 4                                        NaN          96                2
# ...                                      ...         ...              ...
# 500762                                     3           0                4
# 500763                                   NaN           0                2
# 500764                                   NaN           0                2
# 500765                                   NaN           0                2
# 500766                             NO APLICA           0                2
#
#        FECHA AVALUO  GRADO_AVANCE_AREAS_COMUNES  GRADO_TERMINACION_OBRA  \
# 0        08/07/2019                         NaN                     NaN
# 1        03/07/2019                         NaN                     NaN
# 2        06/05/2019                         NaN                     NaN
# 3        16/05/2019                         NaN                     NaN
# 4        01/08/2019                         NaN                     NaN
# ...             ...                         ...                     ...
# 500762   05/06/2019                         NaN                     NaN
# 500763   05/09/2019                         NaN                     NaN
# 500764   13/11/2019                         NaN                     NaN
# 500765   27/11/2019                         NaN                     NaN
# 500766   07/12/2019                         NaN                     NaN
#
#         ID AGUA POTABLE  ID ALUMBRADO  ID BANQUETAS  ID CALIDAD PROYECTO  \
# 0                   1.0           2.0           5.0                  1.0
# 1                   1.0           3.0           1.0                  1.0
# 2                   1.0           2.0           5.0                  1.0
# 3                   1.0           2.0           5.0                  1.0
# 4                   1.0           2.0           5.0                  1.0
# ...                 ...           ...           ...                  ...
# 500762              NaN           NaN           NaN                  NaN
# 500763              NaN           NaN           NaN                  NaN
# 500764              NaN           NaN           NaN                  NaN
# 500765              NaN           NaN           NaN                  NaN
# 500766              NaN           NaN           NaN                  NaN
#
#         ID CLASE  ID CONSERVACION   ID CTL  ID ELEVADOR  ID ENTIDAD  \
# 0              2                3   300285            0          15
# 1              4                6   401083            0          31
# 2              3                4  1742055            0           3
# 3              4                4  1401421            0          11
# 4              4                4  1005370            0           7
# ...          ...              ...      ...          ...         ...
# 500762         5                6  1101252            2          15
# 500763         5                6   903013            2           5
# 500764         5                6  1004886            2          19
# 500765         5                6  1004886            2          19
# 500766         5                6  1538095            2          24
#
#         ID EQUIPAMIENTO  ID GUARNICIONES  ID INFRAESTRUCTURA  \
# 0                     1              3.0                   1
# 1                     1              1.0                   1
# 2                     1              3.0                   2
# 3                     1              3.0                   2
# 4                     1              3.0                   2
# ...                 ...              ...                 ...
# 500762                4              NaN                   3
# 500763                4              NaN                   3
# 500764                4              NaN                   3
# 500765                4              NaN                   3
# 500766                4              NaN                   3
#
#         ID MATERIAL VIALIDADES  ID MUNICIPIO  ID OTORGANTE  \
# 0                            1            22         30003
# 1                            2            13         40012
# 2                            1             8         40086
# 3                            1            14         40161
# 4                            1            65         40012
# ...                        ...           ...           ...
# 500762                       2            13         40062
# 500763                       2            30         40161
# 500764                       2             4         40161
# 500765                       2            48         40002
# 500766                       2            28         30001
#
#         ID PROXIMIDAD URBANA  ID RECOLECCION AGUAS  ID SUMINISTRO ELECTRICO  \
# 0                          4                   3.0                      1.0
# 1                          3                   3.0                      2.0
# 2                          2                   1.0                      1.0
# 3                          2                   2.0                      1.0
# 4                          3                   1.0                      1.0
# ...                      ...                   ...                      ...
# 500762                     3                   NaN                      NaN
# 500763                     3                   NaN                      NaN
# 500764                     3                   NaN                      NaN
# 500765                     3                   NaN                      NaN
# 500766                     3                   NaN                      NaN
#
#         ID SUMINISTRO TELEFONO  ID TIPO  ID TRANSPORTE URBANO  ID UV    ID VP  \
# 0                          1.0        2                   1.0   9045   903377
# 1                          1.0        2                   1.0   9067  1641085
# 2                          1.0        2                   1.0  14011  1844375
# 3                          1.0        2                   1.0   9001  1537935
# 4                          3.0        2                   1.0   9067   300442
# ...                        ...      ...                   ...    ...      ...
# 500762                     NaN        2                   NaN  19001   404202
# 500763                     NaN        2                   NaN  19011   302646
# 500764                     NaN        2                   NaN  19011   408278
# 500765                     NaN        2                   NaN  19011   408278
# 500766                     NaN        2                   NaN   5008   500884
#
#           LATITUD    LONGITUD  NIVEL  NIVELES PROPOSITO  RECAMARAS  \
# 0       19.219444  -98.843058      3        2       S/D          2
# 1       21.052797  -89.519739      3        2       S/D          3
# 2       23.136342 -109.708202      3        1       S/D          2
# 3       21.135174 -100.936490      3        3       S/D          3
# 4       17.494799  -91.984017      3        2       S/D          4
# ...           ...         ...    ...      ...       ...        ...
# 500762  19.566084  -99.319800      3        4       S/D          3
# 500763  25.450562 -100.937260      3        2       S/D          3
# 500764  25.270082 -100.024399      3        2       S/D          3
# 500765  25.677934 -100.460464      3        2       S/D          3
# 500766  22.135803 -101.042714      3        2       S/D          3
#
#         SUP ACCESORIA  SUP CONSTRUIDA  SUP VENDIBLE  SUP TERRENO  \
# 0                0.00           81.96         81.96       250.00
# 1               45.94          160.95        206.89       294.26
# 2                0.00           79.46         79.46       197.50
# 3                0.00          199.10        199.10       258.20
# 4               53.60          192.40        246.00       303.60
# ...               ...             ...           ...          ...
# 500762         127.34          444.74        444.74       967.97
# 500763          33.73          212.46        246.19       231.00
# 500764          87.98          263.74        351.72       479.70
# 500765          44.10          180.16        224.26       144.00
# 500766          48.36          160.57        208.93       180.00
#
#         TRANSPORTE_URBANO_DISTANCIA-1  UNIDADES RENTABLES  \
# 0                                 NaN                 1.0
# 1                                 NaN                 1.0
# 2                                 NaN                 1.0
# 3                                 NaN                 1.0
# 4                                 NaN                 1.0
# ...                               ...                 ...
# 500762                            NaN                 1.0
# 500763                            NaN                 1.0
# 500764                            NaN                 1.0
# 500765                            NaN                 1.0
# 500766                            NaN                 1.0
#
#         UNIDADES RENTABLES SUJETO  \
# 0                             1.0
# 1                             1.0
# 2                             1.0
# 3                             1.0
# 4                             2.0
# ...                           ...
# 500762                        NaN
# 500763                        NaN
# 500764                        NaN
# 500765                        NaN
# 500766                        NaN
#
#                                                USO ACTUAL  VALOR COMPARATIVO  \
# 0                                         CASA HABITACION             584454
# 1                                         CASA HABITACION            1998147
# 2                                         CASA HABITACION             872049
# 3                                         CASA HABITACION            1831700
# 4       PREDIO URBANO DE FORMA REGULAR EN LOTE INTERME...            1706155
# ...                                                   ...                ...
# 500762                                                NaN           11649451
# 500763                                                NaN            3323565
# 500764                                                NaN            5311032
# 500765                                                NaN            3175521
# 500766                                                NaN            3219611
#
#         VALOR CONCLUIDO  VALOR_FISICO_CONSTRUCCION  VALOR_FISICO_TERRENO  \
# 0                584000                  225911.80          3.207500e+05
# 1               1998000                 1403320.00          3.745930e+05
# 2                872000                  458881.50          3.355525e+05
# 3               1832000                  975191.80          5.422200e+05
# 4               1706000                 1356840.00          2.641320e+05
# ...                 ...                        ...                   ...
# 500762         11649000                   32301.47          5.319818e+06
# 500763          3324000                 1570886.00          1.131900e+06
# 500764          5311000                 3484436.50          1.583010e+06
# 500765          3176000                 1819890.00          9.216000e+05
# 500766          3220000                 1712902.00          1.116000e+06
#
#                                               VIAS ACCESO  VIDA UTIL REMANENTE
# 0       VIAS PRIMARIAS:AL ESTE CARRETERA FEDERAL 115 M...                   36
# 1            A 400.00 MTS DE LA CARRETERA MERIDA - MOTUL.                   70
# 2       CAMINO DE ACCESO HASTA ENCONTRAR EL INMUEBLE D...                   41
# 3       CARRETERA FEDERAL 110 Carretera Federal Alto 0...                   50
# 4       POR LA CARRETERA PALENQUE-OCOSINGO VIALIDAD PR...                   62
# ...                                                   ...                  ...
# 500762                                                NaN                   80
# 500763                                                NaN                   80
# 500764                                                NaN                   80
# 500765                                                NaN                   80
# 500766                                                NaN                   80
#
# [500767 rows x 58 columns]

# %%
# see columns
print(df_properties_2019.shape[1])
print(df_properties_2019.columns.tolist())
# Out:
# 58
# ['1/2 BAÑOS', 'BAÑOS', 'CLASE INMUEBLES ZONA', 'COLONIA', 'CONSTRUCTOR', 'CP', 'CUENTA_PREDIAL', 'DESCRIPCION_INSTALACION_ESPECIAL_COMUNES', 'DESCRIPCION_INSTALACION_ESPECIAL_PRIVATIVAS', 'DESCRIPCION_OBRA_COMPLEMENTARIA_COMUN', 'EDAD MESES', 'ESTACIONAMIENTO', 'FECHA AVALUO', 'GRADO_AVANCE_AREAS_COMUNES', 'GRADO_TERMINACION_OBRA', 'ID AGUA POTABLE', 'ID ALUMBRADO', 'ID BANQUETAS', 'ID CALIDAD PROYECTO', 'ID CLASE', 'ID CONSERVACION', 'ID CTL', 'ID ELEVADOR', 'ID ENTIDAD', 'ID EQUIPAMIENTO', 'ID GUARNICIONES', 'ID INFRAESTRUCTURA', 'ID MATERIAL VIALIDADES', 'ID MUNICIPIO', 'ID OTORGANTE', 'ID PROXIMIDAD URBANA', 'ID RECOLECCION AGUAS', 'ID SUMINISTRO ELECTRICO', 'ID SUMINISTRO TELEFONO', 'ID TIPO', 'ID TRANSPORTE URBANO', 'ID UV', 'ID VP', 'LATITUD', 'LONGITUD', 'NIVEL', 'NIVELES', 'PROPOSITO', 'RECAMARAS', 'SUP ACCESORIA', 'SUP CONSTRUIDA', 'SUP VENDIBLE', 'SUP TERRENO', 'TRANSPORTE_URBANO_DISTANCIA-1', 'UNIDADES RENTABLES', 'UNIDADES RENTABLES SUJETO', 'USO ACTUAL', 'VALOR COMPARATIVO', 'VALOR CONCLUIDO', 'VALOR_FISICO_CONSTRUCCION', 'VALOR_FISICO_TERRENO', 'VIAS ACCESO', 'VIDA UTIL REMANENTE']
