# %% [markdown]
# # Join Data Bases
#
# @roman
#
# 5 Oct 2024

# %% [markdown]
# ---
# # Settings

# %%
import os
import pandas as pd
import geopandas as gpd
import uuid
import re
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Settings
# show 100 columns in pandas
pd.set_option('display.max_columns', 100)

# %%
# params
column_mapping = {
    "1/2_banos": "half_bathrooms",
    "banos": "full_bathrooms",
    "clase_inmuebles_zona": "property_class_more_common_in_area",
    "neighborhood": "neighborhood",
    "constructor": "constructor",
    "cp": "zip_code",
    "cuenta_predial": "property_account_id",
    "descripcion_instalacion_especial_comunes": "special_common_installations_description",
    "descripcion_instalacion_especial_privativas": "special_private_installations_description",
    "descripcion_obra_complementaria_comun": "complementary_common_works_description",
    "edad_meses": "age_in_months",
    "estacionamiento": "parking_lots",
    "valuation_date": "valuation_date",
    "grado_avance_areas_comunes": "common_areas_completion_percentage",
    "grado_terminacion_obra": "private_works_completion_percentage",
    "id_agua_potable": "potable_water_service_id",
    "id_alumbrado": "lighting_service_id",
    "id_banquetas": "sidewalk_id",
    "id_calidad_proyecto": "project_quality_id",
    "id_clase": "property_class_id",
    "id_conservacion": "conservation_status_id",
    "id_ctl": "controller_id",
    "id_elevador": "elevator_service_id",
    "id_entidad": "state_id",
    "id_equipamiento": "equipment_id",
    "id_guarniciones": "curb_id",
    "id_infraestructura": "infrastructure_service_id",
    "id_material_vialidades": "road_materials_id",
    "municipality_id": "municipality_id",
    "id_otorgante": "grantor_id",
    "id_proximidad_urbana": "urban_proximity_id",
    "id_recoleccion_aguas": "water_collection_service_id",
    "id_suministro_electrico": "electrical_supply_service_id",
    "id_suministro_telefono": "telephone_service_supply_id",
    "id_tipo": "property_type_id",
    "id_transporte_urbano": "public_transportation_service_id",
    "id_uv": "valuation_unit_id",
    "id_vp": "valuation_professional_id",
    "latitudee": "latitudee",
    "latitudeee": "latitudeee",
    "nivel": "level",
    "niveles": "total_levels",
    "proposito": "purpose_of_appraisal",
    "recamaras": "bedrooms",
    "sup_accesoria": "accessory_area",
    "sup_construida": "built_area",
    "sup_vendible": "saleable_area",
    "sup_terreno": "land_area",
    "transporte_urbano_distancia": "distance_to_public_transportation",
    "unidades_rentables": "rentable_units",
    "unidades_rentables_sujeto": "rentable_units_subject_property",
    "uso_actual": "current_use",
    "valor_comparativo": "market_price",
    "valor_concluido": "price",
    "valor_fisico_construccion": "built_price",
    "valor_fisico_terreno": "land_price",
    "vias_acceso": "access_routes",
    "vida_util_remanente": "remaining_useful_life"
}

# folder data
folder_data = "../../data/raw/"
folder_data_interim = "../../data/interim/"

# %% [markdown]
# ---
# # Data

# %% [markdown]
# ## Read

# %%
def clean_column_names(df):
    # Function to clean column names
    def clean_column(col):
        col = col.lower()  # Lowercase all characters
        col = col.strip()  # Trim leading/trailing whitespace
        col = col.replace(' ', '_')  # Replace spaces with underscores
        # remove accents
        col = col.replace('á', 'a')
        col = col.replace('é', 'e')
        col = col.replace('í', 'i')
        col = col.replace('ó', 'o')
        col = col.replace('ú', 'u')
        col = col.replace('ñ', 'n')
        col = col.replace('ü', 'u')
        col = col.replace('ä', 'a')
        col = col.replace('ë', 'e')
        col = col.replace('ï', 'i')
        col = col.replace('ö', 'o')
        col = col.replace('ü', 'u')
        # remove -1 
        col = col.replace('-1', '')
        
        return col

    # Apply the cleaning function to all columns
    df.columns = [clean_column(col) for col in df.columns]
    return df

def read_all_csv_files_in_folder(folder_path):
    # Read all csv files in a folder
    df = pd.DataFrame()
    for file in os.listdir(folder_path):
        if file.endswith('.csv'):
            print(f'Reading {file}')
            df = pd.concat([df, pd.read_csv(os.path.join(folder_path, file))], ignore_index=True)
            print(f'Shape: {df.shape}')
    return df

def generate_uuid_map(series):
    unique_values = series.unique()
    uuid_map = {val: str(uuid.uuid4()) for val in unique_values}
    return uuid_map

# %%
# read all csv files in folder
df_properties = clean_column_names(read_all_csv_files_in_folder(folder_data))
# Out:
# Reading ITAM_2022_CSV.csv
# Shape: (385251, 58)
# Reading ITAM_2023_CSV.csv
# Shape: (872455, 58)
# Reading ITAM_2021_CSV.csv
# /var/folders/42/2lkg1sf91wv7mjxw6klfcqtc0000gn/T/ipykernel_87327/3497823692.py:35: DtypeWarning: Columns (8,51,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([df, pd.read_csv(os.path.join(folder_path, file))], ignore_index=True)
# Shape: (1363759, 58)
# Reading ITAM_2020_CSV.csv
# /var/folders/42/2lkg1sf91wv7mjxw6klfcqtc0000gn/T/ipykernel_87327/3497823692.py:35: DtypeWarning: Columns (8,51,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([df, pd.read_csv(os.path.join(folder_path, file))], ignore_index=True)
# Shape: (1838477, 58)
# Reading ITAM_2019_CSV.csv
# Shape: (2339244, 58)

# %%
# see columns 8, 51 and 56
df_properties.iloc[:, [8, 51, 56]].describe()
# Out:
#        descripcion_instalacion_especial_privativas       uso_actual  \
# count                                       319545          1534879
# unique                                       10725           275290
# top                                      NO APLICA  CASA HABITACION
# freq                                         76276           276178
#
#                                              vias_acceso
# count                                            1545584
# unique                                            655115
# top     AL NORTE POR EL LIBRAMIENTO MATAMOROS-MONTERREY.
# freq                                                3959

# %%
# see df
print(df_properties.shape[0])
df_properties.head(2)
# Out:
# 2339244
#    1/2_banos  banos  clase_inmuebles_zona                 colonia constructor  \
# 0          1      2                     4  VISTA HERMOSA HUITEPEC   NO APLICA
# 1          1      2                     4                    MAYA   NO APLICA
#
#       cp  cuenta_predial descripcion_instalacion_especial_comunes  \
# 0  29263             NaN                                      NaN
# 1  97134             NaN                                      NaN
#
#   descripcion_instalacion_especial_privativas  \
# 0                                         NaN
# 1                                         NaN
#
#   descripcion_obra_complementaria_comun  edad_meses  estacionamiento  \
# 0                                   NaN          36                1
# 1                                   NaN         204                1
#
#   fecha_avaluo  grado_avance_areas_comunes  grado_terminacion_obra  \
# 0   14/06/2022                         NaN                   100.0
# 1   15/11/2022                         NaN                   100.0
#
#    id_agua_potable  id_alumbrado  id_banquetas  id_calidad_proyecto  id_clase  \
# 0              NaN           NaN           NaN                  NaN         4
# 1              NaN           NaN           NaN                  NaN         4
#
#    id_conservacion   id_ctl  id_elevador  id_entidad  id_equipamiento  \
# 0                4  1844221          0.0           7                1
# 1                4  1641085          0.0          31                2
#
#    id_guarniciones  id_infraestructura  id_material_vialidades  id_municipio  \
# 0              NaN                   1                       2            78
# 1              NaN                   1                       2            50
#
#    id_otorgante  id_proximidad_urbana  id_recoleccion_aguas  \
# 0         40044                     3                   NaN
# 1         40021                     2                   NaN
#
#    id_suministro_electrico  id_suministro_telefono  id_tipo  \
# 0                      NaN                     NaN        2
# 1                      NaN                     NaN        2
#
#    id_transporte_urbano  id_uv    id_vp    latitude   longitude  nivel  niveles  \
# 0                   NaN   9058  1844680  16.737283 -92.672659      3        3
# 1                   NaN   9070   305318  21.014297 -89.575189      3        2
#
#   proposito  recamaras  sup_accesoria  sup_construida  sup_vendible  \
# 0       S/D          3          10.75          216.81        227.56
# 1       S/D          3          13.38          141.55        154.93
#
#    sup_terreno  transporte_urbano_distancia  unidades_rentables  \
# 0        302.7                          NaN                 1.0
# 1        198.0                          NaN                 1.0
#
#    unidades_rentables_sujeto uso_actual  valor_comparativo  valor_concluido  \
# 0                        NaN        NaN            3716737          3717000
# 1                        NaN        NaN            2348706          2349000
#
#    valor_fisico_construccion  valor_fisico_terreno vias_acceso  \
# 0                 2532281.13             1033417.8         NaN
# 1                 1111845.21              984852.0         NaN
#
#    vida_util_remanente
# 0                   67
# 1                   53

# %% [markdown]
# ## Format

# %%
# rename
df_properties = df_properties.rename(columns=column_mapping)

# see df
df_properties.head(2)
# Out:
#    half_bathrooms  full_bathrooms  property_class_more_common_in_area  \
# 0               1               2                                   4
# 1               1               2                                   4
#
#              neighborhood constructor  zip_code  property_account_id  \
# 0  VISTA HERMOSA HUITEPEC   NO APLICA     29263                  NaN
# 1                    MAYA   NO APLICA     97134                  NaN
#
#   special_common_installations_description  \
# 0                                      NaN
# 1                                      NaN
#
#   special_private_installations_description  \
# 0                                       NaN
# 1                                       NaN
#
#   complementary_common_works_description  age_in_months  parking_lots  \
# 0                                    NaN             36             1
# 1                                    NaN            204             1
#
#   valuation_date  common_areas_completion_percentage  \
# 0     14/06/2022                                 NaN
# 1     15/11/2022                                 NaN
#
#    private_works_completion_percentage  potable_water_service_id  \
# 0                                100.0                       NaN
# 1                                100.0                       NaN
#
#    lighting_service_id  sidewalk_id  project_quality_id  property_class_id  \
# 0                  NaN          NaN                 NaN                  4
# 1                  NaN          NaN                 NaN                  4
#
#    conservation_status_id  controller_id  elevator_service_id  state_id  \
# 0                       4        1844221                  0.0         7
# 1                       4        1641085                  0.0        31
#
#    equipment_id  curb_id  infrastructure_service_id  road_materials_id  \
# 0             1      NaN                          1                  2
# 1             2      NaN                          1                  2
#
#    municipality_id  grantor_id  urban_proximity_id  \
# 0               78       40044                   3
# 1               50       40021                   2
#
#    water_collection_service_id  electrical_supply_service_id  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    telephone_service_supply_id  property_type_id  \
# 0                          NaN                 2
# 1                          NaN                 2
#
#    public_transportation_service_id  valuation_unit_id  \
# 0                               NaN               9058
# 1                               NaN               9070
#
#    valuation_professional_id   latitude  longitude  level  total_levels  \
# 0                    1844680  16.737283 -92.672659      3             3
# 1                     305318  21.014297 -89.575189      3             2
#
#   purpose_of_appraisal  bedrooms  accessory_area  built_area  saleable_area  \
# 0                  S/D         3           10.75      216.81         227.56
# 1                  S/D         3           13.38      141.55         154.93
#
#    land_area  distance_to_public_transportation  rentable_units  \
# 0      302.7                                NaN             1.0
# 1      198.0                                NaN             1.0
#
#    rentable_units_subject_property current_use  market_price    price  \
# 0                              NaN         NaN       3716737  3717000
# 1                              NaN         NaN       2348706  2349000
#
#    built_price  land_price access_routes  remaining_useful_life
# 0   2532281.13   1033417.8           NaN                     67
# 1   1111845.21    984852.0           NaN                     53

# %%
# Converting columns to appropriate dtypes
print("datetime columns")
df_properties['valuation_date'] = pd.to_datetime(df_properties['valuation_date'], format='%d/%m/%Y')

# Convert IDs to int64 (if they should not have decimals)
print("id columns")
id_columns = df_properties.columns[df_properties.columns.str.contains('_id')]
# pop valuation ids
valuation_identifiers = ['controller_id', 'grantor_id', 'valuation_unit_id', 'valuation_professional_id']
id_columns = id_columns.drop(valuation_identifiers)
df_properties[valuation_identifiers].isna().sum()
df_properties[id_columns] = df_properties[id_columns].fillna(-1).astype('int64').replace(-1, pd.NA)

# Conver valuation identifiers to hash
print("valuation identifiers")
for col in valuation_identifiers:
    # Generate a mapping from the original values to a new UUID
    col_mapping = generate_uuid_map(df_properties[col])
    # Replace the original values with the UUIDs
    df_properties[col] = df_properties[col].map(col_mapping)

# Convert price columns to float64
print("price columns")
price_columns = df_properties.columns[df_properties.columns.str.contains('price')]
df_properties[price_columns] = df_properties[price_columns].astype('float64')

# Generate observation id
print("observation id")
df_properties['observation_id'] = df_properties.index.map(lambda x: str(uuid.uuid4()))

# Generate property_id
print("property id")
property_idetifiers = valuation_identifiers + ['property_account_id', 'latitude', 'latitude']
df_properties['property_id'] = df_properties[property_idetifiers].astype(str).apply(lambda x: ''.join(x), axis=1).map(lambda x: str(uuid.uuid5(uuid.NAMESPACE_DNS, x)))
# Out:
# datetime columns
# id columns
# valuation identifiers
# price columns
# observation id
# property id

# %%
# see info
df_properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339244 entries, 0 to 2339243
# Data columns (total 60 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   half_bathrooms                             int64
#  1   full_bathrooms                             int64
#  2   property_class_more_common_in_area         int64
#  3   neighborhood                               object
#  4   constructor                                object
#  5   zip_code                                   int64
#  6   property_account_id                        object
#  7   special_common_installations_description   object
#  8   special_private_installations_description  object
#  9   complementary_common_works_description     object
#  10  age_in_months                              int64
#  11  parking_lots                               int64
#  12  valuation_date                             datetime64[ns]
#  13  common_areas_completion_percentage         float64
#  14  private_works_completion_percentage        float64
#  15  potable_water_service_id                   object
#  16  lighting_service_id                        object
#  17  sidewalk_id                                object
#  18  project_quality_id                         object
#  19  property_class_id                          int64
#  20  conservation_status_id                     int64
#  21  controller_id                              object
#  22  elevator_service_id                        object
#  23  state_id                                   int64
#  24  equipment_id                               int64
#  25  curb_id                                    object
#  26  infrastructure_service_id                  int64
#  27  road_materials_id                          int64
#  28  municipality_id                            int64
#  29  grantor_id                                 object
#  30  urban_proximity_id                         int64
#  31  water_collection_service_id                object
#  32  electrical_supply_service_id               object
#  33  telephone_service_supply_id                object
#  34  property_type_id                           int64
#  35  public_transportation_service_id           object
#  36  valuation_unit_id                          object
#  37  valuation_professional_id                  object
#  38  latitude                                   float64
#  39  longitude                                  float64
#  40  level                                      int64
#  41  total_levels                               int64
#  42  purpose_of_appraisal                       object
#  43  bedrooms                                   int64
#  44  accessory_area                             float64
#  45  built_area                                 float64
#  46  saleable_area                              float64
#  47  land_area                                  float64
#  48  distance_to_public_transportation          float64
#  49  rentable_units                             float64
#  50  rentable_units_subject_property            float64
#  51  current_use                                object
#  52  market_price                               float64
#  53  price                                      float64
#  54  built_price                                float64
#  55  land_price                                 float64
#  56  access_routes                              object
#  57  remaining_useful_life                      int64
#  58  observation_id                             object
#  59  property_id                                object
# dtypes: datetime64[ns](1), float64(15), int64(19), object(25)
# memory usage: 1.0+ GB

# %%
# count of valuation ids
df_properties[valuation_identifiers].nunique()
# Out:
# controller_id                1063
# grantor_id                    141
# valuation_unit_id             108
# valuation_professional_id    2526
# dtype: int64

# %%
# counts
for col in id_columns:
    print(df_properties[col].value_counts())
# Out:
# Series([], Name: count, dtype: int64)
# potable_water_service_id
# 1    1541734
# 2       3842
# 3         19
# 0         17
# Name: count, dtype: int64
# lighting_service_id
# 3    908010
# 2    634422
# 1      3123
# 0        90
# Name: count, dtype: int64
# sidewalk_id
# 1    1468809
# 5      43483
# 4      14819
# 3       9555
# 2       1779
# 0        238
# Name: count, dtype: int64
# project_quality_id
# 1    1512106
# 3      10537
# 2       4685
# 0        144
# 4          1
# 5          1
# Name: count, dtype: int64
# property_class_id
# 3    1306412
# 4     835212
# 5     112339
# 2      59499
# 6      22474
# 7       3308
# Name: count, dtype: int64
# conservation_status_id
# 6    1126020
# 4    1062742
# 5     105379
# 7      40234
# 3       4869
# Name: count, dtype: int64
# elevator_service_id
# 2    1767828
# 0     417464
# 1      48142
# Name: count, dtype: int64
# state_id
# 19    268555
# 14    210831
# 15    196358
# 11    125855
# 9     120348
# 8     117914
# 5     112034
# 28    105086
# 30     97410
# 23     89251
# 22     84183
# 26     76312
# 25     74357
# 21     72178
# 13     66855
# 31     59663
# 24     56298
# 1      55046
# 16     47252
# 10     38935
# 2      35085
# 17     34334
# 7      27421
# 27     24213
# 6      24166
# 12     23201
# 18     21767
# 3      20521
# 32     17748
# 29     13246
# 20     12288
# 4      10533
# Name: count, dtype: int64
# equipment_id
# 4    1236872
# 3     841195
# 1     157153
# 2     104024
# Name: count, dtype: int64
# curb_id
# 1    1495242
# 3      41866
# 2       8240
# 0        296
# 4          1
# Name: count, dtype: int64
# infrastructure_service_id
# 3    2066907
# 4     189298
# 2      74126
# 1       8913
# Name: count, dtype: int64
# road_materials_id
# 2    1278309
# 3     647238
# 6     250918
# 1      66349
# 5      51493
# 4      40697
# 8       2758
# 7       1429
# 0         53
# Name: count, dtype: int64
# municipality_id
# 5      99571
# 6      90487
# 20     83340
# 1      82334
# 18     77718
#        ...
# 462        1
# 250        1
# 453        1
# 147        1
# 546        1
# Name: count, Length: 287, dtype: int64
# urban_proximity_id
# 2    1029262
# 3     944492
# 4     235908
# 1     127419
# 5       2163
# Name: count, dtype: int64
# water_collection_service_id
# 1    1467241
# 2      55499
# 3      20111
# 0       2469
# 4        325
# Name: count, dtype: int64
# electrical_supply_service_id
# 2    912575
# 1    585631
# 3     47402
# 0        37
# Name: count, dtype: int64
# telephone_service_supply_id
# 2    790318
# 1    699352
# 3     54038
# 0      1936
# 5         1
# Name: count, dtype: int64
# property_type_id
# 2    1160832
# 3     597118
# 4     540330
# 5      40964
# Name: count, dtype: int64
# public_transportation_service_id
# 1    1501398
# 2      44214
# 0         33
# Name: count, dtype: int64

# %%
# see rows
df_properties
# Out:
#          half_bathrooms  full_bathrooms  property_class_more_common_in_area  \
# 0                     1               2                                   4
# 1                     1               2                                   4
# 2                     0               1                                   3
# 3                     0               1                                   3
# 4                     0               3                                   4
# ...                 ...             ...                                 ...
# 2339239               1               3                                   5
# 2339240               1               4                                   5
# 2339241               1               4                                   5
# 2339242               1               4                                   5
# 2339243               1               4                                   5
#
#                                   neighborhood                  constructor  \
# 0                       VISTA HERMOSA HUITEPEC                    NO APLICA
# 1                                         MAYA                    NO APLICA
# 2                                      KANASIN                    NO APLICA
# 3                                   MULCHECHEN                    NO APLICA
# 4                              POBLACION MOTUL                    NO APLICA
# ...                                        ...                          ...
# 2339239  FRACC RES CAMPESTRE CONDADO SAYAVEDRA                    NO APLICA
# 2339240       FRACCIONAMIENTO VILLAS LA JOYA 2   RODRIGUEZ SILLER ALEJANDRO
# 2339241    FRACCIONAMIENTO PRIVADA SAN AGUSTÍN  RAUL ALEJANDRO MONCADA LEAL
# 2339242    FRACCIONAMIENTO VALLE DE SANTA CRUZ                      GRUMART
# 2339243           NUEVA RINCONADA DE LOS ANDES                    NO APLICA
#
#          zip_code property_account_id  \
# 0           29263                <NA>
# 1           97134                <NA>
# 2           97370                <NA>
# 3           97370                <NA>
# 4           97430                <NA>
# ...           ...                 ...
# 2339239     52938                <NA>
# 2339240     25297                <NA>
# 2339241     67350                <NA>
# 2339242     66362                <NA>
# 2339243     78218                <NA>
#
#         special_common_installations_description  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 2339239                                        3
# 2339240                                      NaN
# 2339241                                      NaN
# 2339242                                      NaN
# 2339243                                NO APLICA
#
#         special_private_installations_description  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 2339239                                       NaN
# 2339240                                       NaN
# 2339241                                       NaN
# 2339242                                       NaN
# 2339243                                       NaN
#
#         complementary_common_works_description  age_in_months  parking_lots  \
# 0                                          NaN             36             1
# 1                                          NaN            204             1
# 2                                          NaN             60             1
# 3                                          NaN            192             1
# 4                                          NaN            372             0
# ...                                        ...            ...           ...
# 2339239                                      3              0             4
# 2339240                                    NaN              0             2
# 2339241                                    NaN              0             2
# 2339242                                    NaN              0             2
# 2339243                              NO APLICA              0             2
#
#         valuation_date  common_areas_completion_percentage  \
# 0           2022-06-14                                 NaN
# 1           2022-11-15                                 NaN
# 2           2022-06-22                                 NaN
# 3           2022-11-01                                 NaN
# 4           2022-11-01                                 NaN
# ...                ...                                 ...
# 2339239     2019-06-05                                 NaN
# 2339240     2019-09-05                                 NaN
# 2339241     2019-11-13                                 NaN
# 2339242     2019-11-27                                 NaN
# 2339243     2019-12-07                                 NaN
#
#          private_works_completion_percentage potable_water_service_id  \
# 0                                      100.0                     <NA>
# 1                                      100.0                     <NA>
# 2                                      100.0                     <NA>
# 3                                      100.0                     <NA>
# 4                                      100.0                     <NA>
# ...                                      ...                      ...
# 2339239                                  NaN                     <NA>
# 2339240                                  NaN                     <NA>
# 2339241                                  NaN                     <NA>
# 2339242                                  NaN                     <NA>
# 2339243                                  NaN                     <NA>
#
#         lighting_service_id sidewalk_id project_quality_id  property_class_id  \
# 0                      <NA>        <NA>               <NA>                  4
# 1                      <NA>        <NA>               <NA>                  4
# 2                      <NA>        <NA>               <NA>                  3
# 3                      <NA>        <NA>               <NA>                  3
# 4                      <NA>        <NA>               <NA>                  4
# ...                     ...         ...                ...                ...
# 2339239                <NA>        <NA>               <NA>                  5
# 2339240                <NA>        <NA>               <NA>                  5
# 2339241                <NA>        <NA>               <NA>                  5
# 2339242                <NA>        <NA>               <NA>                  5
# 2339243                <NA>        <NA>               <NA>                  5
#
#          conservation_status_id                         controller_id  \
# 0                             4  301ef216-0137-4989-bdd0-32bf1adf1e9b
# 1                             4  717559f7-a918-48f7-9356-c79c582d95b3
# 2                             5  8378ef1c-2fdf-4b2a-be29-0e62eb19d753
# 3                             4  8378ef1c-2fdf-4b2a-be29-0e62eb19d753
# 4                             4  1f637d21-f0cb-43be-b989-5923e4c01d94
# ...                         ...                                   ...
# 2339239                       6  6798e530-93e2-4060-abe0-d1121e934d3d
# 2339240                       6  2846e94a-8ee1-40d6-bf05-00884e4ad855
# 2339241                       6  997f8b90-1ff0-491f-a236-dcbe90b0e6b9
# 2339242                       6  997f8b90-1ff0-491f-a236-dcbe90b0e6b9
# 2339243                       6  f4654d31-2cda-4481-9c54-a93dd462adc3
#
#         elevator_service_id  state_id  equipment_id curb_id  \
# 0                         0         7             1    <NA>
# 1                         0        31             2    <NA>
# 2                         2        31             2    <NA>
# 3                         2        31             2    <NA>
# 4                         0        31             1    <NA>
# ...                     ...       ...           ...     ...
# 2339239                   2        15             4    <NA>
# 2339240                   2         5             4    <NA>
# 2339241                   2        19             4    <NA>
# 2339242                   2        19             4    <NA>
# 2339243                   2        24             4    <NA>
#
#          infrastructure_service_id  road_materials_id  municipality_id  \
# 0                                1                  2               78
# 1                                1                  2               50
# 2                                1                  3               41
# 3                                1                  3               41
# 4                                1                  2               52
# ...                            ...                ...              ...
# 2339239                          3                  2               13
# 2339240                          3                  2               30
# 2339241                          3                  2                4
# 2339242                          3                  2               48
# 2339243                          3                  2               28
#
#                                    grantor_id  urban_proximity_id  \
# 0        6f8c15c7-2914-40bb-87ff-59076af288c9                   3
# 1        9a2781c9-b312-453c-86d1-a6e90584a083                   2
# 2        98013144-6a9f-4e08-9255-cb54568d2f5a                   2
# 3        98013144-6a9f-4e08-9255-cb54568d2f5a                   3
# 4        bc0e00ba-8c35-465f-bbcd-61cedf83d6d8                   1
# ...                                       ...                 ...
# 2339239  805697ca-8f29-454c-ba39-1845456073dd                   3
# 2339240  671b3e31-6e21-4149-ae76-b0a4e7eb3a62                   3
# 2339241  671b3e31-6e21-4149-ae76-b0a4e7eb3a62                   3
# 2339242  cc205b62-3269-474a-ae20-3a170c376c5b                   3
# 2339243  98013144-6a9f-4e08-9255-cb54568d2f5a                   3
#
#         water_collection_service_id electrical_supply_service_id  \
# 0                              <NA>                         <NA>
# 1                              <NA>                         <NA>
# 2                              <NA>                         <NA>
# 3                              <NA>                         <NA>
# 4                              <NA>                         <NA>
# ...                             ...                          ...
# 2339239                        <NA>                         <NA>
# 2339240                        <NA>                         <NA>
# 2339241                        <NA>                         <NA>
# 2339242                        <NA>                         <NA>
# 2339243                        <NA>                         <NA>
#
#         telephone_service_supply_id  property_type_id  \
# 0                              <NA>                 2
# 1                              <NA>                 2
# 2                              <NA>                 2
# 3                              <NA>                 2
# 4                              <NA>                 2
# ...                             ...               ...
# 2339239                        <NA>                 2
# 2339240                        <NA>                 2
# 2339241                        <NA>                 2
# 2339242                        <NA>                 2
# 2339243                        <NA>                 2
#
#         public_transportation_service_id  \
# 0                                   <NA>
# 1                                   <NA>
# 2                                   <NA>
# 3                                   <NA>
# 4                                   <NA>
# ...                                  ...
# 2339239                             <NA>
# 2339240                             <NA>
# 2339241                             <NA>
# 2339242                             <NA>
# 2339243                             <NA>
#
#                             valuation_unit_id  \
# 0        35a7806a-f686-4159-be91-16997e86d271
# 1        b3bf58b2-40cc-4edd-bcf1-e4a0b2798533
# 2        4e63856b-ae68-4653-bcaa-86a51d5d7053
# 3        4e63856b-ae68-4653-bcaa-86a51d5d7053
# 4        90a0a9f7-fab3-4170-b3da-db49e122e41b
# ...                                       ...
# 2339239  1ab837db-7f3a-49b5-ac27-3643402e2782
# 2339240  75fe9a3c-92a0-4623-925b-955a08effd0c
# 2339241  75fe9a3c-92a0-4623-925b-955a08effd0c
# 2339242  75fe9a3c-92a0-4623-925b-955a08effd0c
# 2339243  ec10bcb1-5d93-49dd-ae2e-5c3f85e99149
#
#                     valuation_professional_id   latitude   longitude  level  \
# 0        87aa63b6-9005-4ed3-ba44-fcd75453a9e9  16.737283  -92.672659      3
# 1        02af4710-0922-4bed-9763-045ba14e0283  21.014297  -89.575189      3
# 2        a7f6ef17-0933-4138-9aa9-99529929184d  20.928954  -89.546637      3
# 3        923b9bb1-9ab4-4984-93f1-c873b3c26977  20.916897  -89.580945      3
# 4        f6e764a4-141c-4b02-b902-4a158ec58c58  21.096391  -89.285366      3
# ...                                       ...        ...         ...    ...
# 2339239  4aa4dea9-68e6-4464-ae21-98d8c146c957  19.566084  -99.319800      3
# 2339240  b1389b4d-843a-4e88-9893-5164554c79be  25.450562 -100.937260      3
# 2339241  05756a52-0331-4eb5-9e12-ee3e61d877b7  25.270082 -100.024399      3
# 2339242  05756a52-0331-4eb5-9e12-ee3e61d877b7  25.677934 -100.460464      3
# 2339243  a7050bc4-0310-442a-8708-448a94ef8666  22.135803 -101.042714      3
#
#          total_levels purpose_of_appraisal  bedrooms  accessory_area  \
# 0                   3                  S/D         3           10.75
# 1                   2                  S/D         3           13.38
# 2                   1                  S/D         2            1.12
# 3                   1                  S/D         2            2.16
# 4                   2                  S/D         2           19.05
# ...               ...                  ...       ...             ...
# 2339239             4                  S/D         3          127.34
# 2339240             2                  S/D         3           33.73
# 2339241             2                  S/D         3           87.98
# 2339242             2                  S/D         3           44.10
# 2339243             2                  S/D         3           48.36
#
#          built_area  saleable_area  land_area  \
# 0            216.81         227.56     302.70
# 1            141.55         154.93     198.00
# 2             44.35          45.47     144.80
# 3             52.05          54.21     133.75
# 4            229.93         248.98     844.52
# ...             ...            ...        ...
# 2339239      444.74         444.74     967.97
# 2339240      212.46         246.19     231.00
# 2339241      263.74         351.72     479.70
# 2339242      180.16         224.26     144.00
# 2339243      160.57         208.93     180.00
#
#          distance_to_public_transportation  rentable_units  \
# 0                                      NaN             1.0
# 1                                      NaN             1.0
# 2                                      NaN             1.0
# 3                                      NaN             1.0
# 4                                      NaN             1.0
# ...                                    ...             ...
# 2339239                                NaN             1.0
# 2339240                                NaN             1.0
# 2339241                                NaN             1.0
# 2339242                                NaN             1.0
# 2339243                                NaN             1.0
#
#          rentable_units_subject_property current_use  market_price  \
# 0                                    NaN         NaN     3716737.0
# 1                                    NaN         NaN     2348706.0
# 2                                    NaN         NaN      446378.0
# 3                                    NaN         NaN      424468.0
# 4                                    NaN         NaN     2779000.0
# ...                                  ...         ...           ...
# 2339239                              NaN         NaN    11649451.0
# 2339240                              NaN         NaN     3323565.0
# 2339241                              NaN         NaN     5311032.0
# 2339242                              NaN         NaN     3175521.0
# 2339243                              NaN         NaN     3219611.0
#
#               price  built_price    land_price access_routes  \
# 0         3717000.0   2532281.13  1.033418e+06           NaN
# 1         2349000.0   1111845.21  9.848520e+05           NaN
# 2          450000.0    279611.30  1.026632e+05           NaN
# 3          424000.0    290492.55  9.683500e+04           NaN
# 4         2779000.0   1767043.79  6.418352e+05           NaN
# ...             ...          ...           ...           ...
# 2339239  11649000.0     32301.47  5.319818e+06           NaN
# 2339240   3324000.0   1570886.00  1.131900e+06           NaN
# 2339241   5311000.0   3484436.50  1.583010e+06           NaN
# 2339242   3176000.0   1819890.00  9.216000e+05           NaN
# 2339243   3220000.0   1712902.00  1.116000e+06           NaN
#
#          remaining_useful_life                        observation_id  \
# 0                           67  02086af7-ffbb-4e67-b857-27e6cef09b0d
# 1                           53  43c375b2-75fd-4fcc-b311-55b396e7cbbf
# 2                           55  e57ad294-8db8-4ca1-b01f-7ccbc5981922
# 3                           44  f95c14fe-9acc-4b5c-872b-bd15d412a65d
# 4                           39  74af41d9-b7b3-464d-9302-7fd1f231ee26
# ...                        ...                                   ...
# 2339239                     80  37654447-0969-4431-be8c-5b4b0e7114a0
# 2339240                     80  a1fa946a-4115-48eb-ae05-f7ef6d6f38be
# 2339241                     80  329df60f-82e3-4254-81ca-6b0b0e464c8f
# 2339242                     80  2da5a70e-33e0-473e-a0d1-eb3747a0066b
# 2339243                     80  762ad3ef-924f-493f-920c-d92856277270
#
#                                   property_id
# 0        2b225ce9-7742-512e-aac5-846811f1a6a1
# 1        b7f8c282-b67e-5d63-920d-c603b4e2eb52
# 2        552216f4-540b-500d-a4e7-6be55b2b6703
# 3        7215360d-9d5e-538a-971f-15fbef435f54
# 4        5b18adfe-606c-590f-bc76-d3eabfd0ba41
# ...                                       ...
# 2339239  3cb8ed2e-b653-5bd1-97c1-d47c6c00b794
# 2339240  da803a1d-bb97-5af2-8e9c-5525f24a988e
# 2339241  8034e2ce-0b84-5313-afd8-7a95421f7951
# 2339242  da36c0d9-7340-51d7-8d28-89125cebc7bc
# 2339243  2140f4ef-c15b-50e7-9ab1-f5017285d63c
#
# [2339244 rows x 60 columns]

# %%
# memory usage in MB
df_properties.memory_usage().sum() / 1024**2
# Out:
# 1070.821044921875

# %% [markdown]
# ## Dtypes
#
# Coerce to the smallest possible dtype

# %%
def safe_int_convert(series, dtype):
    try:
        return pd.to_numeric(series, errors='coerce').astype(dtype)
    except ValueError:
        return series

# %%
# map
dtypes_mapping = {
    'half_bathrooms': 'uint8',
    'full_bathrooms': 'uint8',
    'property_class_more_common_in_area': 'string',
    'neighborhood': 'string',
    'constructor': 'string',
    'zip_code': 'uint32',
    'property_account_id': 'string',
    'special_common_installations_description': 'string',
    'special_private_installations_description': 'string',
    'complementary_common_works_description': 'string',
    'age_in_months': 'uint8',
    'parking_lots': 'uint8',
    'valuation_date': 'datetime64[ns]',
    'common_areas_completion_percentage': 'float32',
    'private_works_completion_percentage': 'float32',
    'potable_water_service_id': 'uint8',
    'lighting_service_id': 'uint8',
    'sidewalk_id': 'uint8',
    'project_quality_id': 'uint8',
    'property_class_id': 'uint8',
    'conservation_status_id': 'uint8',
    'controller_id': 'string',
    'elevator_service_id': 'uint8',
    'state_id': 'uint8',
    'equipment_id': 'uint8',
    'curb_id': 'uint8',
    'infrastructure_service_id': 'uint8',
    'road_materials_id': 'uint8',
    'municipality_id': 'uint16',
    'grantor_id': 'string',
    'urban_proximity_id': 'uint8',
    'water_collection_service_id': 'uint8',
    'electrical_supply_service_id': 'uint8',
    'telephone_service_supply_id': 'uint8',
    'property_type_id': 'uint8',
    'public_transportation_service_id': 'uint8',
    'valuation_unit_id': 'string',
    'valuation_professional_id': 'string',
    'latitudee': 'float64',
    'latitudeee': 'float64',
    'level': 'uint8',
    'total_levels': 'uint8',
    'purpose_of_appraisal': 'string',
    'bedrooms': 'uint8',
    'accessory_area': 'float32',
    'built_area': 'float32',
    'saleable_area': 'float32',
    'land_area': 'float32',
    'distance_to_public_transportation': 'float32',
    'rentable_units': 'uint32',
    'rentable_units_subject_property': 'uint32',
    'current_use': 'string',
    'market_price': 'float64',
    'price': 'float64',
    'built_price': 'float64',
    'land_price': 'float64',
    'access_routes': 'string',
    'remaining_useful_life': 'int16',  # some errors on this column
    'observation_id': 'string',
    'property_id': 'string'
}

# Convert
# all int columns first nan to np.nan
print("dtype int columns")
# any int column
int_columns = [col for col in dtypes_mapping if re.search('int', dtypes_mapping[col])]
# int columns
for col in int_columns:
    df_properties[col] = safe_int_convert(df_properties[col], dtypes_mapping[col])


# convert other columns
print("dtype other columns")
dtypes_non_integer = {k: v for k, v in dtypes_mapping.items() if k not in int_columns}
df_properties = df_properties.astype(dtypes_non_integer)
# Out:
# dtype int columns
# dtype other columns

# %%
# see info
df_properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339244 entries, 0 to 2339243
# Data columns (total 60 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   half_bathrooms                             uint8
#  1   full_bathrooms                             uint8
#  2   property_class_more_common_in_area         string
#  3   neighborhood                               string
#  4   constructor                                string
#  5   zip_code                                   uint32
#  6   property_account_id                        string
#  7   special_common_installations_description   string
#  8   special_private_installations_description  string
#  9   complementary_common_works_description     string
#  10  age_in_months                              uint8
#  11  parking_lots                               uint8
#  12  valuation_date                             datetime64[ns]
#  13  common_areas_completion_percentage         float32
#  14  private_works_completion_percentage        float32
#  15  potable_water_service_id                   object
#  16  lighting_service_id                        object
#  17  sidewalk_id                                object
#  18  project_quality_id                         object
#  19  property_class_id                          uint8
#  20  conservation_status_id                     uint8
#  21  controller_id                              string
#  22  elevator_service_id                        object
#  23  state_id                                   uint8
#  24  equipment_id                               uint8
#  25  curb_id                                    object
#  26  infrastructure_service_id                  uint8
#  27  road_materials_id                          uint8
#  28  municipality_id                            uint16
#  29  grantor_id                                 string
#  30  urban_proximity_id                         uint8
#  31  water_collection_service_id                object
#  32  electrical_supply_service_id               object
#  33  telephone_service_supply_id                object
#  34  property_type_id                           uint8
#  35  public_transportation_service_id           object
#  36  valuation_unit_id                          string
#  37  valuation_professional_id                  string
#  38  latitude                                   float64
#  39  longitude                                  float64
#  40  level                                      uint8
#  41  total_levels                               uint8
#  42  purpose_of_appraisal                       string
#  43  bedrooms                                   uint8
#  44  accessory_area                             float32
#  45  built_area                                 float32
#  46  saleable_area                              float32
#  47  land_area                                  float32
#  48  distance_to_public_transportation          float32
#  49  rentable_units                             float64
#  50  rentable_units_subject_property            float64
#  51  current_use                                string
#  52  market_price                               float64
#  53  price                                      float64
#  54  built_price                                float64
#  55  land_price                                 float64
#  56  access_routes                              string
#  57  remaining_useful_life                      int16
#  58  observation_id                             string
#  59  property_id                                string
# dtypes: datetime64[ns](1), float32(7), float64(8), int16(1), object(10), string(16), uint16(1), uint32(1), uint8(15)
# memory usage: 738.4+ MB

# %%
# memory usage in MB
df_properties.memory_usage().sum() / 1024**2
# Out:
# 738.4203834533691

# %%
# counts
for col in id_columns:
    print(df_properties[col].value_counts())
# Out:
# Series([], Name: count, dtype: Int64)
# potable_water_service_id
# 1    1541734
# 2       3842
# 3         19
# 0         17
# Name: count, dtype: int64
# lighting_service_id
# 3    908010
# 2    634422
# 1      3123
# 0        90
# Name: count, dtype: int64
# sidewalk_id
# 1    1468809
# 5      43483
# 4      14819
# 3       9555
# 2       1779
# 0        238
# Name: count, dtype: int64
# project_quality_id
# 1    1512106
# 3      10537
# 2       4685
# 0        144
# 4          1
# 5          1
# Name: count, dtype: int64
# property_class_id
# 3    1306412
# 4     835212
# 5     112339
# 2      59499
# 6      22474
# 7       3308
# Name: count, dtype: int64
# conservation_status_id
# 6    1126020
# 4    1062742
# 5     105379
# 7      40234
# 3       4869
# Name: count, dtype: int64
# elevator_service_id
# 2    1767828
# 0     417464
# 1      48142
# Name: count, dtype: int64
# state_id
# 19    268555
# 14    210831
# 15    196358
# 11    125855
# 9     120348
# 8     117914
# 5     112034
# 28    105086
# 30     97410
# 23     89251
# 22     84183
# 26     76312
# 25     74357
# 21     72178
# 13     66855
# 31     59663
# 24     56298
# 1      55046
# 16     47252
# 10     38935
# 2      35085
# 17     34334
# 7      27421
# 27     24213
# 6      24166
# 12     23201
# 18     21767
# 3      20521
# 32     17748
# 29     13246
# 20     12288
# 4      10533
# Name: count, dtype: int64
# equipment_id
# 4    1236872
# 3     841195
# 1     157153
# 2     104024
# Name: count, dtype: int64
# curb_id
# 1    1495242
# 3      41866
# 2       8240
# 0        296
# 4          1
# Name: count, dtype: int64
# infrastructure_service_id
# 3    2066907
# 4     189298
# 2      74126
# 1       8913
# Name: count, dtype: int64
# road_materials_id
# 2    1278309
# 3     647238
# 6     250918
# 1      66349
# 5      51493
# 4      40697
# 8       2758
# 7       1429
# 0         53
# Name: count, dtype: int64
# municipality_id
# 5      99571
# 6      90487
# 20     83340
# 1      82334
# 18     77718
#        ...
# 462        1
# 250        1
# 453        1
# 147        1
# 546        1
# Name: count, Length: 287, dtype: int64
# urban_proximity_id
# 2    1029262
# 3     944492
# 4     235908
# 1     127419
# 5       2163
# Name: count, dtype: int64
# water_collection_service_id
# 1    1467241
# 2      55499
# 3      20111
# 0       2469
# 4        325
# Name: count, dtype: int64
# electrical_supply_service_id
# 2    912575
# 1    585631
# 3     47402
# 0        37
# Name: count, dtype: int64
# telephone_service_supply_id
# 2    790318
# 1    699352
# 3     54038
# 0      1936
# 5         1
# Name: count, dtype: int64
# property_type_id
# 2    1160832
# 3     597118
# 4     540330
# 5      40964
# Name: count, dtype: int64
# public_transportation_service_id
# 1    1501398
# 2      44214
# 0         33
# Name: count, dtype: int64

# %% [markdown]
# ---
# # Save

# %%
# save
print("saving ...")
df_properties.to_parquet(folder_data + 'appraisals.parquet', index=False)
# Out:
# saving ...

# %% [markdown]
# ---
# # Sandbox

# %%
# count of valuation ids
df_properties[valuation_identifiers].nunique()
# Out:
# controller_id                1063
# grantor_id                    141
# valuation_unit_id             108
# valuation_professional_id    2526
# dtype: int64

# %%
# count of property ids
df_properties['property_id'].value_counts().sort_values(ascending=False)
# Out:
# property_id
# e53135c9-dcf8-5cd2-9b66-689e536ab6c3    319
# 18e27699-a0d1-5ecb-88ca-35b4d6bae7d8    239
# 77b3182c-edd9-5b1b-93dc-bf96f7c4fd3b    202
# 365c430e-13f8-51d7-b964-bd10723edf86    188
# 0fa57e0a-a526-563d-aab8-9f7b2acc3768    141
#                                        ...
# b626ad33-5f49-5255-9e2c-5a87b1be0c80      1
# 85ff3227-a44d-58a6-9045-f97a5e464910      1
# 3e31b5d6-1789-5d2f-9d5d-1bcac2dfc8f9      1
# 49a32f6f-2fb9-58bf-82e7-131fb88a1bfb      1
# 2140f4ef-c15b-50e7-9ab1-f5017285d63c      1
# Name: count, Length: 2093312, dtype: Int64

# %%
# count of repeated properties (more than one)
id_repetead_properties = df_properties['property_id'].value_counts()[df_properties['property_id'].value_counts().gt(1)].index

# count of repeated properties
print(f"repeated properties: {len(id_repetead_properties)}")
print(f"total obs: {df_properties['property_id'].value_counts()[id_repetead_properties].sum()}")
print(f"avg repeated properties: {df_properties['property_id'].value_counts()[id_repetead_properties].mean()}")
# Out:
# repeated properties: 147400
# total obs: 393332
# avg repeated properties: 2.6684667571234737

# %%
# count of observation ids
df_properties['remaining_useful_life'].describe()
# Out:
# count    2.339244e+06
# mean     5.847166e+01
# std      1.112246e+01
# min     -9.000000e+00
# 25%      5.200000e+01
# 50%      6.000000e+01
# 75%      6.900000e+01
# max      8.000000e+01
# Name: remaining_useful_life, dtype: float64

# %%
# describe id columns
df_properties[id_columns].describe()
# Out:
#        property_class_id  conservation_status_id      state_id  equipment_id  \
# count       2.339244e+06            2.339244e+06  2.339244e+06  2.339244e+06
# mean        3.462134e+00            5.057287e+00  1.666580e+01  3.349917e+00
# std         6.856368e-01            1.004745e+00  7.953309e+00  8.482336e-01
# min         2.000000e+00            3.000000e+00  1.000000e+00  1.000000e+00
# 25%         3.000000e+00            4.000000e+00  1.100000e+01  3.000000e+00
# 50%         3.000000e+00            5.000000e+00  1.500000e+01  4.000000e+00
# 75%         4.000000e+00            6.000000e+00  2.300000e+01  4.000000e+00
# max         7.000000e+00            7.000000e+00  3.200000e+01  4.000000e+00
#
#        infrastructure_service_id  road_materials_id  municipality_id  \
# count               2.339244e+06       2.339244e+06     2.339244e+06
# mean                3.041614e+00       2.788298e+00     4.028076e+01
# std                 3.551336e-01       1.313538e+00     4.494025e+01
# min                 1.000000e+00       0.000000e+00     0.000000e+00
# 25%                 3.000000e+00       2.000000e+00     1.100000e+01
# 50%                 3.000000e+00       2.000000e+00     2.700000e+01
# 75%                 3.000000e+00       3.000000e+00     5.000000e+01
# max                 4.000000e+00       8.000000e+00     5.700000e+02
#
#        urban_proximity_id  property_type_id
# count        2.339244e+06      2.339244e+06
# mean         2.553759e+00      2.769766e+00
# std          7.505294e-01      8.627087e-01
# min          1.000000e+00      2.000000e+00
# 25%          2.000000e+00      2.000000e+00
# 50%          3.000000e+00      3.000000e+00
# 75%          3.000000e+00      3.000000e+00
# max          5.000000e+00      5.000000e+00

# %%
# municipality
df_properties['state_id']
# Out:
# 0           7
# 1          31
# 2          31
# 3          31
# 4          31
#            ..
# 2339239    15
# 2339240     5
# 2339241    19
# 2339242    19
# 2339243    24
# Name: state_id, Length: 2339244, dtype: uint8

# %%
# describe price
cols = [
    'remaining_useful_life'
]
df_properties[cols].describe()
# Out:
#        remaining_useful_life
# count           2.339244e+06
# mean            5.847166e+01
# std             1.112246e+01
# min            -9.000000e+00
# 25%             5.200000e+01
# 50%             6.000000e+01
# 75%             6.900000e+01
# max             8.000000e+01

# %%
# read parquet
df2 = pd.read_parquet(folder_data + 'appraisals.parquet')

# see info
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339244 entries, 0 to 2339243
# Data columns (total 60 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   half_bathrooms                             uint8
#  1   full_bathrooms                             uint8
#  2   property_class_more_common_in_area         string
#  3   neighborhood                               string
#  4   constructor                                string
#  5   zip_code                                   uint32
#  6   property_account_id                        string
#  7   special_common_installations_description   string
#  8   special_private_installations_description  string
#  9   complementary_common_works_description     string
#  10  age_in_months                              uint8
#  11  parking_lots                               uint8
#  12  valuation_date                             datetime64[ns]
#  13  common_areas_completion_percentage         float32
#  14  private_works_completion_percentage        float32
#  15  potable_water_service_id                   float64
#  16  lighting_service_id                        float64
#  17  sidewalk_id                                float64
#  18  project_quality_id                         float64
#  19  property_class_id                          uint8
#  20  conservation_status_id                     uint8
#  21  controller_id                              string
#  22  elevator_service_id                        float64
#  23  state_id                                   uint8
#  24  equipment_id                               uint8
#  25  curb_id                                    float64
#  26  infrastructure_service_id                  uint8
#  27  road_materials_id                          uint8
#  28  municipality_id                            uint16
#  29  grantor_id                                 string
#  30  urban_proximity_id                         uint8
#  31  water_collection_service_id                float64
#  32  electrical_supply_service_id               float64
#  33  telephone_service_supply_id                float64
#  34  property_type_id                           uint8
#  35  public_transportation_service_id           float64
#  36  valuation_unit_id                          string
#  37  valuation_professional_id                  string
#  38  latitude                                   float64
#  39  longitude                                  float64
#  40  level                                      uint8
#  41  total_levels                               uint8
#  42  purpose_of_appraisal                       string
#  43  bedrooms                                   uint8
#  44  accessory_area                             float32
#  45  built_area                                 float32
#  46  saleable_area                              float32
#  47  land_area                                  float32
#  48  distance_to_public_transportation          float32
#  49  rentable_units                             float64
#  50  rentable_units_subject_property            float64
#  51  current_use                                string
#  52  market_price                               float64
#  53  price                                      float64
#  54  built_price                                float64
#  55  land_price                                 float64
#  56  access_routes                              string
#  57  remaining_useful_life                      int16
#  58  observation_id                             string
#  59  property_id                                string
# dtypes: datetime64[ns](1), float32(7), float64(18), int16(1), string(16), uint16(1), uint32(1), uint8(15)
# memory usage: 738.4 MB
